# %%
# Step 1: Import library
import pandas as pd

# %%
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Sentiment.csv')

# %%
df.head()
# Out:
#                                      text sentiment
# 0  Loved the experience, will book again!  positive
# 1     Terrible host and very dirty place.  negative
# 2           It was okay, nothing special.   neutral
# 3     Amazing location and friendly host.  positive
# 4            Worst stay ever, very noisy.  negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       300 non-null    object
#  1   sentiment  300 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#                                           text sentiment
# count                                      300       300
# unique                                       6         3
# top     Loved the experience, will book again!  positive
# freq                                        50       100

# %%
df.columns
# Out:
# Index(['text', 'sentiment'], dtype='object')

# %%
y = df['sentiment']

# %%
X = df['text'].astype(str)

# %%
# Step 4: train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,train_size=0.75,random_state=42)
X.shape, X_train.shape, X_test.shape
# Out:
# ((300,), (225,), (75,))

# %%
# TFiDF
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=2000,ngram_range=(1, 2),stop_words="english")

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
X_train
# Out:
# 282    Loved the experience, will book again!
# 82               Worst stay ever, very noisy.
# 84     Loved the experience, will book again!
# 66     Loved the experience, will book again!
# 288    Loved the experience, will book again!
#                         ...
# 188             It was okay, nothing special.
# 71          Quite good overall, minor issues.
# 106              Worst stay ever, very noisy.
# 270    Loved the experience, will book again!
# 102    Loved the experience, will book again!
# Name: text, Length: 225, dtype: object

# %%
y_train
# Out:
# 282    positive
# 82     negative
# 84     positive
# 66     positive
# 288    positive
#          ...
# 188     neutral
# 71      neutral
# 106    negative
# 270    positive
# 102    positive
# Name: sentiment, Length: 225, dtype: object

# %%
# Step 5: Select Model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# Step 6: Train model
model.fit(X_train_tfidf,y_train)
# Out:
# LogisticRegression()

# %%
model.coef_
# Out:
# array([[-0.49164447, -0.49164447, -0.50743842,  0.9258645 ,  0.9258645 ,
#         -0.50743842, -0.50743842, -0.49164447, -0.49164447, -0.37621325,
#         -0.37621325,  0.33825434,  0.9258645 , -0.37621325, -0.49164447,
#         -0.49164447, -0.50743842, -0.50743842, -0.37621325, -0.37621325,
#          1.03089222, -0.66827716, -0.66827716, -0.37621325, -0.37621325,
#          0.9258645 , -0.37621325, -0.37621325, -0.66827716,  1.03089222,
#          1.03089222,  0.9258645 ,  0.9258645 ,  1.03089222,  1.03089222],
#        [-0.43303496, -0.43303496, -0.51377312, -0.43571794, -0.43571794,
#         -0.51377312, -0.51377312, -0.43303496, -0.43303496,  0.74713055,
#          0.74713055, -0.65650415, -0.43571794,  0.74713055, -0.43303496,
#         -0.43303496, -0.51377312, -0.51377312,  0.74713055,  0.74713055,
#         -0.52121797,  1.32707768,  1.32707768,  0.74713055,  0.74713055,
#         -0.43571794,  0.74713055,  0.74713055,  1.32707768, -0.52121797,
#         -0.52121797, -0.43571794, -0.43571794, -0.52121797, -0.52121797],
#        [ 0.92467943,  0.92467943,  1.02121154, -0.49014656, -0.49014656,
#          1.02121154,  1.02121154,  0.92467943,  0.92467943, -0.3709173 ,
#         -0.3709173 ,  0.31824981, -0.49014656, -0.3709173 ,  0.92467943,
#          0.92467943,  1.02121154,  1.02121154, -0.3709173 , -0.3709173 ,
#         -0.50967425, -0.65880052, -0.65880052, -0.3709173 , -0.3709173 ,
#         -0.49014656, -0.3709173 , -0.3709173 , -0.65880052, -0.50967425,
#         -0.50967425, -0.49014656, -0.49014656, -0.50967425, -0.50967425]])

# %%
model.intercept_
# Out:
# array([ 0.00186939,  0.02672041, -0.02858981])

# %%
# Step 7: Predict
y_pred = model.predict(X_test_tfidf)

# %%
# Step 8: Evaluate model
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(X_test_tfidf)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        23
#      neutral       1.00      1.00      1.00        24
#     positive       1.00      1.00      1.00        28
#
#     accuracy                           1.00        75
#    macro avg       1.00      1.00      1.00        75
# weighted avg       1.00      1.00      1.00        75
